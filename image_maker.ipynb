# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
filepath = "Output_files/BH_Image.csv"
def show_BH(filename,save_to=False):
    with open(filepath, 'r') as f:
        runinfo = f.readlines()
        #runinfo.split('\n')

        #config data
        config = runinfo[:14]
        #image data
        data = runinfo[14:]
    print(data)
    plt.imshow(data.transpose, cmap='hot', extent=[-30, 30, -20, 20])

# %%
filepath = "Output_files/BH_Image.csv"
def show_BH(filename,save_to=False, print_config=False):
    data = pd.read_csv(filepath, header=15)
    plt.imshow(data.transpose(), cmap='hot', extent=[-30, 30, -20, 20])
    if print_config is True:
        # Open the file
        with open('Output_files/BH_Image.csv', 'r') as file:
            # Read the first 14 lines
            first_14_lines = [next(file) for _ in range(14)]

        # Print the first 14 lines
        for line in first_14_lines:
            print(line, end='')

# %%
show_BH("BH_Image.csv",print_config=True)
# Out:
# Configuration:
# savename: BH_Image
# theta0: 1.39626
# xres: 320
# yres: 240
# a: 0.99
# M: 1
# rin: 5
# rout: 20
# thetathick: 0.01
# D: 500
# xsize: 30
# ysize: 20
